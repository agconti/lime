# %% [markdown]
# ### Lime API | By Andrew Conti

# %%
import sys
sys.path.append('C:\Users\Andrew\Documents\Kaggle\lime')
from lime_API import lime

# %%
lime = lime()

# %%
single_data = lime.get_single('AAPL')

# %%
single_data.price.plot()
plt.title("Apple stock movements on: " + str(lime.start_date))

# %%
many = lime.get_many(begining_date=datetime.date(2013,5,2), end_date=datetime.date(2013,6,3), ticker='AAPL')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-d8e55be5755b> in <module>()
# ----> 1 many = lime.get_many(begining_date=datetime.date(2013,5,2), end_date=datetime.date(2013,6,3), ticker='AAPL')
#
# C:\Users\Andrew\Documents\Kaggle\lime\lime_API.py in get_many(self, begining_date, ticker, end_date, *args, **kwargs)
#     132         for single_date in date_range(start=begining_date, end=self.end_date, freq='B'):
#     133             self.start_date = self.lime_date_parse(single_date)
# --> 134             if df.columns > 1:
#     135                 concat([df, self.get_single(self.ticker)])
#     136             else:
#
# AttributeError: 'str' object has no attribute 'columns'

# %% [markdown]
# ###Version Control:

# %%
# !git add lime_demo.ipynb

# %%
# !git commit
# Out:
# Aborting commit due to empty commit message.
